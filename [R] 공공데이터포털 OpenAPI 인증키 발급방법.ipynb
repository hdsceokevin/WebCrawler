# %%
# 기본 설정
library(IRdisplay)
library(repr)
options(repr.plot.width=8, repr.plot.height=6)

# %% [markdown]
# # 공공데이터포털 OpenAPI 인증키 발급 방법

# %%
# 공공데이터포털에 접속 후, 회원가입 및 로그인을 합니다. 
# 상단 검색창에 "나라장터"를 입력합니다. 
display_png(file="./Image/공공데이터포털 메인화면.png")

# %%
# 검색 결과 화면을 보면, 상단에 "전체", "파일데이터", "오픈API", "표준데이터" 메뉴가 보입니다. 
# 그 중에서 "오픈API"를 선택합니다. 
# 리스트 하단에 "조달청_낙찰정보"를 클릭합니다. 
display_png(file="./Image/나라장터 오픈API 리스트.png")

# %%
# "조달청_낙찰정보" 상세화면에서 "활용신청"을 클릭합니다. 
display_png(file="./Image/조달청 낙찰정보 API.png")

# %%
# 개발계정 신청화면으로 이동한 후 "상세기능정보" 테이블에서 필요한 상세기능 앞에 체크합니다.
display_png(file="./Image/조달청 낙찰정보 API 개발계정 신청1.png")

# %%
# 필요한 상세기능을 다 신청한 후 "라이센스표시 - 동의합니다" 체크 후 "신청"을 클릭합니다. 
display_png(file="./Image/조달청 낙찰정보 API 개발계정 신청2.png")

# %%
# 이제 API 인증키 신청이 완료되었습니다. 
# 확인을 클릭하면 "마이페이지 > OPEN API > 개발계정"으로 이동하여 인증키를 확인할 수 있습니다. 
display_png(file="./Image/조달청 낙찰정보 API 개발계정 신청3.png")

# %%
# "서비스정보"의 "일반 인증키"를 이용하여 XML을 수집할 수 있습니다.
# "참고문서"를 다운로드한 후 해당 항목을 꼼꼼하게 읽어보시는 것을 권해드립니다. 
display_png(file="./Image/조달청 낙찰정보 API Key 확인.png")

# %% [markdown]
# # End of Document
